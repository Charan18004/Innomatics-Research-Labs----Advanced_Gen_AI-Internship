# %% [markdown]
# <a href="https://colab.research.google.com/github/Charan18004/Innomatics-Research-Labs----Advanced_Gen_AI-Internship/blob/main/logincheck%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# user credentials
username = "admin"
password = "1234"

# user input
u = input("enter username :")
p = input("enter password :")

#login check
if(u==username and p==password):
  print("Login Successful")
else:
  print("Invalid Credentials")
# Out:
# enter username :admin
# enter password :1234
# Login Successful
